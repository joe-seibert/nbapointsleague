# %%
import numpy as np
import pandas as pd

# %%
from nba_api.stats.endpoints import playercareerstats
from nba_api.stats.static import players
from nba_api.stats.endpoints import commonplayerinfo
from nba_api.stats.endpoints.commonallplayers import CommonAllPlayers
from nba_api.stats.endpoints import playergamelog

# %%
big_fundamental = [player for player in nba_players
                   if player['full_name'] == 'Tim Duncan'][0]

# %%
big_fundamental
# Out:
# {'id': 1495,
#  'full_name': 'Tim Duncan',
#  'first_name': 'Tim',
#  'last_name': 'Duncan',
#  'is_active': False}

# %%
player_list = ['Damian Lillard','Kevin Durant','Russell Westbrook']

# %%
# Basic Request
player_info = commonplayerinfo.CommonPlayerInfo(player_id=2544)

# %%
player_info.common_player_info.get_data_frame()
# Out:
#    PERSON_ID FIRST_NAME LAST_NAME DISPLAY_FIRST_LAST DISPLAY_LAST_COMMA_FIRST  \
# 0       2544     LeBron     James       LeBron James            James, LeBron
#
#   DISPLAY_FI_LAST   PLAYER_SLUG            BIRTHDATE  \
# 0        L. James  lebron-james  1984-12-30T00:00:00
#
#                          SCHOOL COUNTRY  ...    TEAM_CITY    PLAYERCODE  \
# 0  St. Vincent-St. Mary HS (OH)     USA  ...  Los Angeles  lebron_james
#
#   FROM_YEAR  TO_YEAR DLEAGUE_FLAG NBA_FLAG GAMES_PLAYED_FLAG DRAFT_YEAR  \
# 0      2003     2020            N        Y                 Y       2003
#
#    DRAFT_ROUND DRAFT_NUMBER
# 0            1            1
#
# [1 rows x 32 columns]

# %%
player_info.player_headline_stats.get_data_frame()
# Out:
#    PLAYER_ID   PLAYER_NAME TimeFrame   PTS  AST  REB    PIE
# 0       2544  LeBron James   2020-21  22.8  6.5  7.5  0.165

# %%
from nba_api.stats.endpoints.commonallplayers import CommonAllPlayers

# %%
df = CommonAllPlayers().common_all_players.get_data_frame()

# %%
CommonAllPlayers().common_all_players.get_data_frame().query("DISPLAY_FIRST_LAST == 'Damian Lillard'")
# Out:
#       PERSON_ID DISPLAY_LAST_COMMA_FIRST DISPLAY_FIRST_LAST  ROSTERSTATUS  \
# 2428     203081          Lillard, Damian     Damian Lillard             1
#
#      FROM_YEAR TO_YEAR      PLAYERCODE     TEAM_ID TEAM_CITY      TEAM_NAME  \
# 2428      2012    2020  damian_lillard  1610612757  Portland  Trail Blazers
#
#      TEAM_ABBREVIATION TEAM_CODE GAMES_PLAYED_FLAG OTHERLEAGUE_EXPERIENCE_CH
# 2428               POR   blazers                 Y                        00

# %%
player_info = commonplayerinfo.CommonPlayerInfo(player_id=203081)

# %%
player_info.player_headline_stats.get_json()
# Out:
# '{"headers": ["PLAYER_ID", "PLAYER_NAME", "TimeFrame", "PTS", "AST", "REB", "PIE"], "data": [[203081, "Damian Lillard", "2020-21", 24.0, 7.0, 4.3, 0.127]]}'

# %%
df.loc[df['DISPLAY_FIRST_LAST'].isin(player_list)]
# Out:
# 1097    201142
# 2428    203081
# 4331    201566
# Name: PERSON_ID, dtype: int64

# %%
from nba_api.stats.endpoints import playergamelog

# %%
playergamelog.PlayerGameLog(player_id = 203081,season=2020).get_data_frames()[0]
# Out:
#   SEASON_ID  Player_ID     Game_ID     GAME_DATE      MATCHUP WL  MIN  FGM  \
# 0     22020     203081  0022000045  DEC 28, 2020    POR @ LAL  W   36   10
# 1     22020     203081  0022000029  DEC 26, 2020  POR vs. HOU  W   41   11
# 2     22020     203081  0022000020  DEC 23, 2020  POR vs. UTA  L   34    4
#
#    FGA  FG_PCT  ...  DREB  REB  AST  STL  BLK  TOV  PF  PTS  PLUS_MINUS  \
# 0   16   0.625  ...     4    4    5    0    1    5   1   31         -10
# 1   28   0.393  ...     4    5    9    1    0    5   1   32           7
# 2   12   0.333  ...     4    4    7    1    1    1   1    9         -21
#
#    VIDEO_AVAILABLE
# 0                1
# 1                1
# 2                1
#
# [3 rows x 27 columns]

# %%
from nba_api.stats.endpoints import playervsplayer

# %%
playervsplayer.PlayerVsPlayer(player_id=203081,vs_player_id=201142).get_data_frames()[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# WantReadError                             Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
# ...

# %%
playergamelog.PlayerGameLog(player_id = 201142,season=2020).get_data_frames()[0]
# Out:
#   SEASON_ID  Player_ID     Game_ID     GAME_DATE      MATCHUP WL  MIN  FGM  \
# 0     22020     201142  0022000032  DEC 27, 2020    BKN @ CHA  L   36    9
# 1     22020     201142  0022000007  DEC 25, 2020    BKN @ BOS  W   33    9
# 2     22020     201142  0022000001  DEC 22, 2020  BKN vs. GSW  W   25    7
#
#    FGA  FG_PCT  ...  DREB  REB  AST  STL  BLK  TOV  PF  PTS  PLUS_MINUS  \
# 0   15   0.600  ...     3    3    4    0    1    3   3   29           7
# 1   16   0.563  ...     4    4    3    2    0    2   3   29          31
# 2   16   0.438  ...     4    5    3    3    1    1   3   22          26
#
#    VIDEO_AVAILABLE
# 0                1
# 1                1
# 2                1
#
# [3 rows x 27 columns]

# %%
def get_player_id(player_list,common_all_players):
    player_array = []
    
    use_player_list = common_all_players.loc[common_all_players['DISPLAY_FIRST_LAST'].isin(player_list)]
    
    for index,row in use_player_list.iterrows():
        player_array.append({'player_name': row['DISPLAY_FIRST_LAST'],'player_id': row['PERSON_ID']})
        
    return player_array

# %%
get_player_id(player_list,df)
# Out:
# [{'player_name': 'Kevin Durant', 'player_id': 201142},
#  {'player_name': 'Damian Lillard', 'player_id': 203081},
#  {'player_name': 'Russell Westbrook', 'player_id': 201566}]

# %%
sheet_id = '16KJmOPm_2zAl2W1X2w265an-d7yMolOMfmITrTINsfI'
